# %%
ingredients=['Ambrette Seed',
'Apple Cinnamon Granola',
'Arizona Seasoning',
'Americano Coffee',
'Baby Abalone',
'Cadbury Double Decker Chocolate Bar',
'Campari Tomato',
'Celery Soup',
'Chia Meal',
'Crunch Bars',
'Cardamom',
'Giardiniera',
'Hog Maw',
'Mccormick Montreal Steak Seasoning',
'Muesli',
'Mulberry',
'Munch Chocolate',
'Murukku Packet',
'Mango',
'Organic Maize',
'Organic Peruvian Groundcherry',
'Organic Tartar Cream',
'Orange Extract',
'Pickled Cauliflower',
'Pork Chump Chops','Pork Lungs',
'Pork Tripe',
'Peanut Butter',
'Smokies Sausage',
'Snickers Spread',
'Strawberry Gelatin',
'Salmon',
'Tomato',
'Tamarind',
'Vegan Carob Chips',
'Vegan Chicken Strips',
'Vegan Chorizo',
'Vegan Marshmallow',
'Vegan Puff Pastry Sheet',
'Vegan Semisweet Chocolate Chips',
'Vegan White Cake',
'Vegetable Stock',
'Vinegar']
article='''munchbox meals munchbox is a geelong-based boutique meal prep and delivery service,
specialising in artisan vegan and vegetarian meals and munchies. with a passion for
providing delicious and nutritious food that is ethical, sustainable and affordable, all
munchbox meals are made from scratch using a balance of the freshest local and organic
vegetables and fruit, grains, seeds and nuts and homegrown herbs. we chat to eden callick –
the brains behind the business – about all things munchbox. hey! thanks for chatting to forte!
first up, can you explain how munchbox became to be? munchbox was a daydream turned
reality. i was in a really draining job i hated, and would spend the majority of my lunch-break
looking for vegan food. the struggle to find a tasty, good quality, vegan meal is real.
sometimes it was so real i’d just give up looking, and go hungry. one day i hungrily and
jokingly announced, ‘i’m going to open my own vegan food business’ and with that impulsive
announcement, i quit my job almost immediately, and promised myself i would put my whole
heart and soul in to becoming the best vegan chef i can be. with a whole lot of determination,
passion and support from those around me, munchbox was born and is now my baby! i
guess a little bit of selfishness for me to have passion and purpose in life, as well as the lack
of real quality vegan cuisine on the geelong food scene is really how munchbox came to be
– out of necessity. where did your passion for vegan/vegetarian food come from? i’ve always
had a love and passion for food, but it wasn’t until i slowly transitioned to vegan that my
passion turned into a true obsession! it opened a whole new door for experimentation in the
kitchen; i want to create cruelty free food that tastes and looks better, but most importantly is
better for you! nothing makes me happier then feeding people and changing their views on
vegan food. can you give our readers a run-down of how ‘munchbox’ works? munchbox is
an artisan meal prep and delivery service, providing chef made meals to you. our munchers
can order online any time before friday midnight, with meals being ready for pick-up or
delivery on sunday. ready for the week ahead! these hours will soon be changing to include
24/7 online ordering, with pick-up and delivery between 7am-7pm seven days a week. all
meals come ready to eat or heat; those that are best enjoyed heated include a lit flame! we
also specialise in events and corporate catering; so, if there’s a bunch that’s got the munch,
we’re here to feed your sweet souls! where have you gathered most of your recipes and
ideas from? i’m constantly gathering ideas and inspiration from anywhere and everywhere! i
have a collection of paper scraps with scribbled recipes, and sleep with a notebook next to
my bed just in case i dream up a new idea. i have mood-boards, and future menu lists. it’s a
mess really! i find so much inspiration and ideas from traditional non-vegan meals, and have
been fortunate enough to work alongside some amazing non-vegan chefs who have (taught)
and inspired me incredibly. my mumma and sister, who are huge vegan foodies, are always
coming up with insane recipes for me as well. but each recipe is ultimately my own, made
from scratch, tried and tested until it’s perfected. how do you determine what local and
organic ingredients make the cut? we are passionately committed to sustainability and
supporting our local community. our menus are always based around the freshest seasonal
produce, sourced from local organic farmers, as well as other artisan vegan businesses who
supply some of our ingredients. we also lovingly grow all our own herbs, and as munchbox
expands so will our veggie garden; to include some pretty crazy exotic fruit and vege! what
type of people does this service suit? munchbox is perfect for those who are time poor, but
hungry, and care what they put in to their body. looking for a delicious and nutritious meal,
that isn’t frozen or full of crap. we put all the freshness, flavour, love and care into each meal,
so you don’t have to! breaky, lunch, or tea, pick up or delivery, we’ve got you covered so you
don’t have to think about cooking a thing! munchbox isn’t exclusively for vegetarians or
vegans, but is perfect for those looking to try a tasty healthy alternative! do you do custom
orders? or is everything off the set menu? yes! all our meals are fully customisable to suit
diet and taste! don’t like tomato? just let us know! gluten intolerant? we got you! you can add
or remove any ingredients and extras in our meals when you order. however, if you’d like our
chefs to create something extra special just for you, we’re more than happy to! we can
customise personalised menus, meal plans and munchboxes just for you! where are you
hoping to take munchbox in future? munchbox has big plans for the future! you can expect
an ever-changing menu (to keep up with my ever-changing mind). we’ll be incorporating
menulog and uber eats as apart of our service, and expanding trading hours and service
locations in the very near future. there may also be plans for ‘munch mobile’ to attend
festivals, markets, and events.. but i can’t give too much away! we have sooo many
surprises for ya’ll, but i can’t spoil them all at once! check it out via insta @vegan.munchbox
or you can get your munch on at munchboxmeals.com.au'''

# %%
len(ingredients)
# Out:
# 43

# %%
from nltk import tokenize
from operator import itemgetter
import math

from nltk.corpus import stopwords
#from nltk.tokenize import word_tokenize
stop_words=set(stopwords.words('english'))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
words = [word for word in article.split() if word.lower() not in stop_words]
for i in range(len(words)):
    if words[i][-1] in {',','!','?'}:
        words[i]=words[i][0:len(words[i])-1]
new_text = " ".join(words)

# %%
words
# Out:
# ['munchbox',
#  'meals',
#  'munchbox',
#  'geelong-based',
#  'boutique',
#  'meal',
#  'prep',
#  'delivery',
#  'service',
#  'specialising',
#  'artisan',
#  'vegan',
#  'vegetarian',
#  'meals',
#  'munchies.',
#  'passion',
#  'providing',
#  'delicious',
#  'nutritious',
#  'food',
#  'ethical',
#  'sustainable',
#  'affordable',
#  'munchbox',
#  'meals',
#  'made',
#  'scratch',
#  'using',
#  'balance',
#  'freshest',
#  'local',
#  'organic',
#  'vegetables',
#  'fruit',
#  'grains',
#  'seeds',
#  'nuts',
#  'homegrown',
#  'herbs.',
#  'chat',
#  'eden',
#  'callick',
#  '–',
#  'brains',
#  'behind',
#  'business',
#  '–',
#  'things',
#  'munchbox.',
#  'hey',
#  'thanks',
#  'chatting',
#  'forte',
#  'first',
#  'up',
#  'explain',
#  'munchbox',
#  'became',
#  'be',
#  'munchbox',
#  'daydream',
#  'turned',
#  'reality.',
#  'really',
#  'draining',
#  'job',
#  'hated',
#  'would',
#  'spend',
#  'majority',
#  'lunch-break',
#  'looking',
#  'vegan',
#  'food.',
#  'struggle',
#  'find',
#  'tasty',
#  'good',
#  'quality',
#  'vegan',
#  'meal',
#  'real.',
#  'sometimes',
#  'real',
#  'i’d',
#  'give',
#  'looking',
#  'go',
#  'hungry.',
#  'one',
#  'day',
#  'hungrily',
#  'jokingly',
#  'announced',
#  '‘i’m',
#  'going',
#  'open',
#  'vegan',
#  'food',
#  'business’',
#  'impulsive',
#  'announcement',
#  'quit',
#  'job',
#  'almost',
#  'immediately',
#  'promised',
#  'would',
#  'put',
#  'whole',
#  'heart',
#  'soul',
#  'becoming',
#  'best',
#  'vegan',
#  'chef',
#  'be.',
#  'whole',
#  'lot',
#  'determination',
#  'passion',
#  'support',
#  'around',
#  'me',
#  'munchbox',
#  'born',
#  'baby',
#  'guess',
#  'little',
#  'bit',
#  'selfishness',
#  'passion',
#  'purpose',
#  'life',
#  'well',
#  'lack',
#  'real',
#  'quality',
#  'vegan',
#  'cuisine',
#  'geelong',
#  'food',
#  'scene',
#  'really',
#  'munchbox',
#  'came',
#  '–',
#  'necessity.',
#  'passion',
#  'vegan/vegetarian',
#  'food',
#  'come',
#  'from',
#  'i’ve',
#  'always',
#  'love',
#  'passion',
#  'food',
#  'wasn’t',
#  'slowly',
#  'transitioned',
#  'vegan',
#  'passion',
#  'turned',
#  'true',
#  'obsession',
#  'opened',
#  'whole',
#  'new',
#  'door',
#  'experimentation',
#  'kitchen;',
#  'want',
#  'create',
#  'cruelty',
#  'free',
#  'food',
#  'tastes',
#  'looks',
#  'better',
#  'importantly',
#  'better',
#  'you',
#  'nothing',
#  'makes',
#  'happier',
#  'feeding',
#  'people',
#  'changing',
#  'views',
#  'vegan',
#  'food.',
#  'give',
#  'readers',
#  'run-down',
#  '‘munchbox’',
#  'works',
#  'munchbox',
#  'artisan',
#  'meal',
#  'prep',
#  'delivery',
#  'service',
#  'providing',
#  'chef',
#  'made',
#  'meals',
#  'you.',
#  'munchers',
#  'order',
#  'online',
#  'time',
#  'friday',
#  'midnight',
#  'meals',
#  'ready',
#  'pick-up',
#  'delivery',
#  'sunday.',
#  'ready',
#  'week',
#  'ahead',
#  'hours',
#  'soon',
#  'changing',
#  'include',
#  '24/7',
#  'online',
#  'ordering',
#  'pick-up',
#  'delivery',
#  '7am-7pm',
#  'seven',
#  'days',
#  'week.',
#  'meals',
#  'come',
#  'ready',
#  'eat',
#  'heat;',
#  'best',
#  'enjoyed',
#  'heated',
#  'include',
#  'lit',
#  'flame',
#  'also',
#  'specialise',
#  'events',
#  'corporate',
#  'catering;',
#  'so',
#  'there’s',
#  'bunch',
#  'that’s',
#  'got',
#  'munch',
#  'we’re',
#  'feed',
#  'sweet',
#  'souls',
#  'gathered',
#  'recipes',
#  'ideas',
#  'from',
#  'i’m',
#  'constantly',
#  'gathering',
#  'ideas',
#  'inspiration',
#  'anywhere',
#  'everywhere',
#  'collection',
#  'paper',
#  'scraps',
#  'scribbled',
#  'recipes',
#  'sleep',
#  'notebook',
#  'next',
#  'bed',
#  'case',
#  'dream',
#  'new',
#  'idea.',
#  'mood-boards',
#  'future',
#  'menu',
#  'lists.',
#  'it’s',
#  'mess',
#  'really',
#  'find',
#  'much',
#  'inspiration',
#  'ideas',
#  'traditional',
#  'non-vegan',
#  'meals',
#  'fortunate',
#  'enough',
#  'work',
#  'alongside',
#  'amazing',
#  'non-vegan',
#  'chefs',
#  '(taught)',
#  'inspired',
#  'incredibly.',
#  'mumma',
#  'sister',
#  'huge',
#  'vegan',
#  'foodies',
#  'always',
#  'coming',
#  'insane',
#  'recipes',
#  'well.',
#  'recipe',
#  'ultimately',
#  'own',
#  'made',
#  'scratch',
#  'tried',
#  'tested',
#  'it’s',
#  'perfected.',
#  'determine',
#  'local',
#  'organic',
#  'ingredients',
#  'make',
#  'cut',
#  'passionately',
#  'committed',
#  'sustainability',
#  'supporting',
#  'local',
#  'community.',
#  'menus',
#  'always',
#  'based',
#  'around',
#  'freshest',
#  'seasonal',
#  'produce',
#  'sourced',
#  'local',
#  'organic',
#  'farmers',
#  'well',
#  'artisan',
#  'vegan',
#  'businesses',
#  'supply',
#  'ingredients.',
#  'also',
#  'lovingly',
#  'grow',
#  'herbs',
#  'munchbox',
#  'expands',
#  'veggie',
#  'garden;',
#  'include',
#  'pretty',
#  'crazy',
#  'exotic',
#  'fruit',
#  'vege',
#  'type',
#  'people',
#  'service',
#  'suit',
#  'munchbox',
#  'perfect',
#  'time',
#  'poor',
#  'hungry',
#  'care',
#  'put',
#  'body.',
#  'looking',
#  'delicious',
#  'nutritious',
#  'meal',
#  'isn’t',
#  'frozen',
#  'full',
#  'crap.',
#  'put',
#  'freshness',
#  'flavour',
#  'love',
#  'care',
#  'meal',
#  'don’t',
#  'to',
#  'breaky',
#  'lunch',
#  'tea',
#  'pick',
#  'delivery',
#  'we’ve',
#  'got',
#  'covered',
#  'don’t',
#  'think',
#  'cooking',
#  'thing',
#  'munchbox',
#  'isn’t',
#  'exclusively',
#  'vegetarians',
#  'vegans',
#  'perfect',
#  'looking',
#  'try',
#  'tasty',
#  'healthy',
#  'alternative',
#  'custom',
#  'orders',
#  'everything',
#  'set',
#  'menu',
#  'yes',
#  'meals',
#  'fully',
#  'customisable',
#  'suit',
#  'diet',
#  'taste',
#  'don’t',
#  'like',
#  'tomato',
#  'let',
#  'us',
#  'know',
#  'gluten',
#  'intolerant',
#  'got',
#  'you',
#  'add',
#  'remove',
#  'ingredients',
#  'extras',
#  'meals',
#  'order.',
#  'however',
#  'you’d',
#  'like',
#  'chefs',
#  'create',
#  'something',
#  'extra',
#  'special',
#  'you',
#  'we’re',
#  'happy',
#  'to',
#  'customise',
#  'personalised',
#  'menus',
#  'meal',
#  'plans',
#  'munchboxes',
#  'you',
#  'hoping',
#  'take',
#  'munchbox',
#  'future',
#  'munchbox',
#  'big',
#  'plans',
#  'future',
#  'expect',
#  'ever-changing',
#  'menu',
#  '(to',
#  'keep',
#  'ever-changing',
#  'mind).',
#  'we’ll',
#  'incorporating',
#  'menulog',
#  'uber',
#  'eats',
#  'apart',
#  'service',
#  'expanding',
#  'trading',
#  'hours',
#  'service',
#  'locations',
#  'near',
#  'future.',
#  'may',
#  'also',
#  'plans',
#  '‘munch',
#  'mobile’',
#  'attend',
#  'festivals',
#  'markets',
#  'events..',
#  'can’t',
#  'give',
#  'much',
#  'away',
#  'sooo',
#  'many',
#  'surprises',
#  'ya’ll',
#  'can’t',
#  'spoil',
#  'once',
#  'check',
#  'via',
#  'insta',
#  '@vegan.munchbox',
#  'get',
#  'munch',
#  'munchboxmeals.com.au']

# %%
len(words)
# Out:
# 525

# %%
rank_list=[]
high_priority=[]
for i in range(len(ingredients)):
    for j in range(len(ingredients[i].split())):
        if ingredients[i].split()[j].lower() in words:
            high_priority.append(ingredients[i])

# %%
high_priority
# Out:
# ['Baby Abalone',
#  'Campari Tomato',
#  'Chia Meal',
#  'Munch Chocolate',
#  'Organic Maize',
#  'Organic Peruvian Groundcherry',
#  'Organic Tartar Cream',
#  'Tomato',
#  'Vegan Carob Chips',
#  'Vegan Chicken Strips',
#  'Vegan Chorizo',
#  'Vegan Marshmallow',
#  'Vegan Puff Pastry Sheet',
#  'Vegan Semisweet Chocolate Chips',
#  'Vegan White Cake']

# %%
import nltk
from collections import Counter
def content_text(text):
    global without_stp
    stopwords = set(nltk.corpus.stopwords.words('english'))
    with_stp = Counter()
    without_stp  = Counter()
    for word in text:
        # update count off all words in the line that are in stopwords
        word = word.lower()
        if word in stopwords:
             with_stp.update([word])
        else:
           # update count off all words in the line that are not in stopwords
            without_stp.update([word])
    # return a list with top ten most common words from each
    return [y for y,_ in without_stp.most_common(20)]
a=[]
for i in range(len(article.split())):
    if article.split()[i][-1] in {'?',',','!'}:
        a.append(article.split()[i][0:len(article.split()[i])-1])
    else:
        a.append(article.split()[i])

print(content_text(a))
repeated=content_text(a)
# Out:
# ['munchbox', 'vegan', 'meals', 'meal', 'passion', 'food', 'delivery', 'service', 'local', 'looking', 'artisan', 'made', 'organic', '–', 'really', 'give', 'put', 'whole', 'always', 'ready']

# %%
without_stp
# Out:
# Counter({'munchbox': 13,
#          'meals': 9,
#          'geelong-based': 1,
#          'boutique': 1,
#          'meal': 6,
#          'prep': 2,
#          'delivery': 5,
#          'service': 5,
#          'specialising': 1,
#          'artisan': 3,
#          'vegan': 10,
#          'vegetarian': 1,
#          'munchies.': 1,
#          'passion': 6,
#          'providing': 2,
#          'delicious': 2,
#          'nutritious': 2,
#          'food': 6,
#          'ethical': 1,
#          'sustainable': 1,
#          'affordable': 1,
#          'made': 3,
#          'scratch': 2,
#          'using': 1,
#          'balance': 1,
#          'freshest': 2,
#          'local': 4,
#          'organic': 3,
#          'vegetables': 1,
#          'fruit': 2,
#          'grains': 1,
#          'seeds': 1,
#          'nuts': 1,
#          'homegrown': 1,
#          'herbs.': 1,
#          'chat': 1,
#          'eden': 1,
#          'callick': 1,
#          '–': 3,
#          'brains': 1,
#          'behind': 1,
#          'business': 1,
#          'things': 1,
#          'munchbox.': 1,
#          'hey': 1,
#          'thanks': 1,
#          'chatting': 1,
#          'forte': 1,
#          'first': 1,
#          'explain': 1,
#          'became': 1,
#          'daydream': 1,
#          'turned': 2,
#          'reality.': 1,
#          'really': 3,
#          'draining': 1,
#          'job': 2,
#          'hated': 1,
#          'would': 2,
#          'spend': 1,
#          'majority': 1,
#          'lunch-break': 1,
#          'looking': 4,
#          'food.': 2,
#          'struggle': 1,
#          'find': 2,
#          'tasty': 2,
#          'good': 1,
#          'quality': 2,
#          'real.': 1,
#          'sometimes': 1,
#          'real': 2,
#          'i’d': 1,
#          'give': 3,
#          'go': 1,
#          'hungry.': 1,
#          'one': 1,
#          'day': 1,
#          'hungrily': 1,
#          'jokingly': 1,
#          'announced': 1,
#          '‘i’m': 1,
#          'going': 1,
#          'open': 1,
#          'business’': 1,
#          'impulsive': 1,
#          'announcement': 1,
#          'quit': 1,
#          'almost': 1,
#          'immediately': 1,
#          'promised': 1,
#          'put': 3,
#          'whole': 3,
#          'heart': 1,
#          'soul': 1,
#          'becoming': 1,
#          'best': 2,
#          'chef': 2,
#          'be.': 1,
#          'lot': 1,
#          'determination': 1,
#          'support': 1,
#          'around': 2,
#          'born': 1,
#          'baby': 1,
#          'guess': 1,
#          'little': 1,
#          'bit': 1,
#          'selfishness': 1,
#          'purpose': 1,
#          'life': 1,
#          'well': 2,
#          'lack': 1,
#          'cuisine': 1,
#          'geelong': 1,
#          'scene': 1,
#          'came': 1,
#          'necessity.': 1,
#          'vegan/vegetarian': 1,
#          'come': 2,
#          'i’ve': 1,
#          'always': 3,
#          'love': 2,
#          'wasn’t': 1,
#          'slowly': 1,
#          'transitioned': 1,
#          'true': 1,
#          'obsession': 1,
#          'opened': 1,
#          'new': 2,
#          'door': 1,
#          'experimentation': 1,
#          'kitchen;': 1,
#          'want': 1,
#          'create': 2,
#          'cruelty': 1,
#          'free': 1,
#          'tastes': 1,
#          'looks': 1,
#          'better': 2,
#          'importantly': 1,
#          'nothing': 1,
#          'makes': 1,
#          'happier': 1,
#          'feeding': 1,
#          'people': 2,
#          'changing': 2,
#          'views': 1,
#          'readers': 1,
#          'run-down': 1,
#          '‘munchbox’': 1,
#          'works': 1,
#          'you.': 1,
#          'munchers': 1,
#          'order': 1,
#          'online': 2,
#          'time': 2,
#          'friday': 1,
#          'midnight': 1,
#          'ready': 3,
#          'pick-up': 2,
#          'sunday.': 1,
#          'week': 1,
#          'ahead': 1,
#          'hours': 2,
#          'soon': 1,
#          'include': 3,
#          '24/7': 1,
#          'ordering': 1,
#          '7am-7pm': 1,
#          'seven': 1,
#          'days': 1,
#          'week.': 1,
#          'eat': 1,
#          'heat;': 1,
#          'enjoyed': 1,
#          'heated': 1,
#          'lit': 1,
#          'flame': 1,
#          'also': 3,
#          'specialise': 1,
#          'events': 1,
#          'corporate': 1,
#          'catering;': 1,
#          'there’s': 1,
#          'bunch': 1,
#          'that’s': 1,
#          'got': 3,
#          'munch': 2,
#          'we’re': 2,
#          'feed': 1,
#          'sweet': 1,
#          'souls': 1,
#          'gathered': 1,
#          'recipes': 3,
#          'ideas': 3,
#          'i’m': 1,
#          'constantly': 1,
#          'gathering': 1,
#          'inspiration': 2,
#          'anywhere': 1,
#          'everywhere': 1,
#          'collection': 1,
#          'paper': 1,
#          'scraps': 1,
#          'scribbled': 1,
#          'sleep': 1,
#          'notebook': 1,
#          'next': 1,
#          'bed': 1,
#          'case': 1,
#          'dream': 1,
#          'idea.': 1,
#          'mood-boards': 1,
#          'future': 3,
#          'menu': 3,
#          'lists.': 1,
#          'it’s': 2,
#          'mess': 1,
#          'much': 2,
#          'traditional': 1,
#          'non-vegan': 2,
#          'fortunate': 1,
#          'enough': 1,
#          'work': 1,
#          'alongside': 1,
#          'amazing': 1,
#          'chefs': 2,
#          '(taught)': 1,
#          'inspired': 1,
#          'incredibly.': 1,
#          'mumma': 1,
#          'sister': 1,
#          'huge': 1,
#          'foodies': 1,
#          'coming': 1,
#          'insane': 1,
#          'well.': 1,
#          'recipe': 1,
#          'ultimately': 1,
#          'tried': 1,
#          'tested': 1,
#          'perfected.': 1,
#          'determine': 1,
#          'ingredients': 2,
#          'make': 1,
#          'cut': 1,
#          'passionately': 1,
#          'committed': 1,
#          'sustainability': 1,
#          'supporting': 1,
#          'community.': 1,
#          'menus': 2,
#          'based': 1,
#          'seasonal': 1,
#          'produce': 1,
#          'sourced': 1,
#          'farmers': 1,
#          'businesses': 1,
#          'supply': 1,
#          'ingredients.': 1,
#          'lovingly': 1,
#          'grow': 1,
#          'herbs': 1,
#          'expands': 1,
#          'veggie': 1,
#          'garden;': 1,
#          'pretty': 1,
#          'crazy': 1,
#          'exotic': 1,
#          'vege': 1,
#          'type': 1,
#          'suit': 2,
#          'perfect': 2,
#          'poor': 1,
#          'hungry': 1,
#          'care': 2,
#          'body.': 1,
#          'isn’t': 2,
#          'frozen': 1,
#          'full': 1,
#          'crap.': 1,
#          'freshness': 1,
#          'flavour': 1,
#          'don’t': 3,
#          'breaky': 1,
#          'lunch': 1,
#          'tea': 1,
#          'pick': 1,
#          'we’ve': 1,
#          'covered': 1,
#          'think': 1,
#          'cooking': 1,
#          'thing': 1,
#          'exclusively': 1,
#          'vegetarians': 1,
#          'vegans': 1,
#          'try': 1,
#          'healthy': 1,
#          'alternative': 1,
#          'custom': 1,
#          'orders': 1,
#          'everything': 1,
#          'set': 1,
#          'yes': 1,
#          'fully': 1,
#          'customisable': 1,
#          'diet': 1,
#          'taste': 1,
#          'like': 2,
#          'tomato': 1,
#          'let': 1,
#          'us': 1,
#          'know': 1,
#          'gluten': 1,
#          'intolerant': 1,
#          'add': 1,
#          'remove': 1,
#          'extras': 1,
#          'order.': 1,
#          'however': 1,
#          'you’d': 1,
#          'something': 1,
#          'extra': 1,
#          'special': 1,
#          'happy': 1,
#          'customise': 1,
#          'personalised': 1,
#          'plans': 3,
#          'munchboxes': 1,
#          'hoping': 1,
#          'take': 1,
#          'big': 1,
#          'expect': 1,
#          'ever-changing': 2,
#          '(to': 1,
#          'keep': 1,
#          'mind).': 1,
#          'we’ll': 1,
#          'incorporating': 1,
#          'menulog': 1,
#          'uber': 1,
#          'eats': 1,
#          'apart': 1,
#          'expanding': 1,
#          'trading': 1,
#          'locations': 1,
#          'near': 1,
#          'future.': 1,
#          'may': 1,
#          '‘munch': 1,
#          'mobile’': 1,
#          'attend': 1,
#          'festivals': 1,
#          'markets': 1,
#          'events..': 1,
#          'can’t': 2,
#          'away': 1,
#          'sooo': 1,
#          'many': 1,
#          'surprises': 1,
#          'ya’ll': 1,
#          'spoil': 1,
#          'check': 1,
#          'via': 1,
#          'insta': 1,
#          '@vegan.munchbox': 1,
#          'get': 1,
#          'munchboxmeals.com.au': 1})

# %%
pip install google
# Out:
# Requirement already satisfied: google in c:\users\dell\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\lib\site-packages (from google) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4->google) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\dell\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
from googlesearch import search
match=[]
marking=[]
d={}
for k in range(len(ingredients)):
    
    text= ingredients[k]
    url = 'https://google.com/search?q=' + text  
    import bs4
    # Fetch the URL data using requests.get(url),
    # store it in a variable, request_result.
    request_result=requests.get( url )
  
    # Creating soup from the fetched request
    soup = bs4.BeautifulSoup(request_result.text,
                         "html.parser")
    #print(soup)
    heading_object=soup.find_all( 'h3' )
  
    # Iterate through the object 
    # and print it as a string.
    full_extracted=[]
    counter_full_extracted=[]
    for info in heading_object:
        p=(info.getText().lower().split())
        for i in range(len(p)):
            if p[i] not in full_extracted:
                full_extracted.append(p[i])
                counter_full_extracted.append(1)
            else:
                ind=full_extracted.index(p[i])
                counter_full_extracted[ind]+=1


        #print(p)
    #print(full_extracted)
    #q=ingredients[k].lower().split()
    #q.extend(repeated)

    #print(q)
    def common_member(a, b):   
        global counter_com_words
        counter_com_words=[]
        result = [i for i in a if i in b]
        for i in result:
            ind=full_extracted.index(i)
            counter_com_words.append(counter_full_extracted[ind])
        return result
    #print(common_member(full_extracted, words))
    l=common_member(full_extracted,words)
    marks=0
    
    for i in range(len(l)):
        marks+=without_stp[l[i]]*counter_full_extracted[i]
    marking.append(marks)
    d[ingredients[k]]=marks
    match.append(len(common_member(full_extracted,words)))

# %%
match
# Out:
# [4,
#  5,
#  4,
#  3,
#  3,
#  0,
#  4,
#  7,
#  13,
#  5,
#  4,
#  6,
#  4,
#  2,
#  4,
#  1,
#  4,
#  5,
#  1,
#  6,
#  5,
#  6,
#  0,
#  5,
#  7,
#  10,
#  5,
#  10,
#  4,
#  1,
#  8,
#  2,
#  1,
#  5,
#  8,
#  7,
#  7,
#  14,
#  10,
#  7,
#  4,
#  10,
#  3]

# %%
len(match)
# Out:
# 43

# %%
marking
# Out:
# [25,
#  38,
#  34,
#  21,
#  23,
#  0,
#  34,
#  69,
#  70,
#  18,
#  15,
#  47,
#  18,
#  10,
#  67,
#  13,
#  36,
#  25,
#  22,
#  51,
#  52,
#  117,
#  0,
#  17,
#  29,
#  32,
#  10,
#  86,
#  26,
#  48,
#  62,
#  38,
#  8,
#  41,
#  47,
#  105,
#  120,
#  108,
#  59,
#  40,
#  116,
#  60,
#  14]

# %%
marking.sort(reverse=True)

# %%
d
# Out:
# {'Ambrette Seed': 25,
#  'Apple Cinnamon Granola': 38,
#  'Arizona Seasoning': 34,
#  'Americano Coffee': 21,
#  'Baby Abalone': 23,
#  'Cadbury Double Decker Chocolate Bar': 0,
#  'Campari Tomato': 34,
#  'Celery Soup': 69,
#  'Chia Meal': 70,
#  'Crunch Bars': 18,
#  'Cardamom': 15,
#  'Giardiniera': 47,
#  'Hog Maw': 18,
#  'Mccormick Montreal Steak Seasoning': 10,
#  'Muesli': 67,
#  'Mulberry': 13,
#  'Munch Chocolate': 36,
#  'Murukku Packet': 25,
#  'Mango': 22,
#  'Organic Maize': 51,
#  'Organic Peruvian Groundcherry': 52,
#  'Organic Tartar Cream': 117,
#  'Orange Extract': 0,
#  'Pickled Cauliflower': 17,
#  'Pork Chump Chops': 29,
#  'Pork Lungs': 32,
#  'Pork Tripe': 10,
#  'Peanut Butter': 86,
#  'Smokies Sausage': 26,
#  'Snickers Spread': 48,
#  'Strawberry Gelatin': 62,
#  'Salmon': 38,
#  'Tomato': 8,
#  'Tamarind': 41,
#  'Vegan Carob Chips': 47,
#  'Vegan Chicken Strips': 105,
#  'Vegan Chorizo': 120,
#  'Vegan Marshmallow': 108,
#  'Vegan Puff Pastry Sheet': 59,
#  'Vegan Semisweet Chocolate Chips': 40,
#  'Vegan White Cake': 116,
#  'Vegetable Stock': 60,
#  'Vinegar': 14}

# %%
import operator
d
sorted_d = sorted(d.items(), key=operator.itemgetter(1),reverse=True)

# %%
sorted_d
# Out:
# [('Vegan Chorizo', 120),
#  ('Organic Tartar Cream', 117),
#  ('Vegan White Cake', 116),
#  ('Vegan Marshmallow', 108),
#  ('Vegan Chicken Strips', 105),
#  ('Peanut Butter', 86),
#  ('Chia Meal', 70),
#  ('Celery Soup', 69),
#  ('Muesli', 67),
#  ('Strawberry Gelatin', 62),
#  ('Vegetable Stock', 60),
#  ('Vegan Puff Pastry Sheet', 59),
#  ('Organic Peruvian Groundcherry', 52),
#  ('Organic Maize', 51),
#  ('Snickers Spread', 48),
#  ('Giardiniera', 47),
#  ('Vegan Carob Chips', 47),
#  ('Tamarind', 41),
#  ('Vegan Semisweet Chocolate Chips', 40),
#  ('Apple Cinnamon Granola', 38),
#  ('Salmon', 38),
#  ('Munch Chocolate', 36),
#  ('Arizona Seasoning', 34),
#  ('Campari Tomato', 34),
#  ('Pork Lungs', 32),
#  ('Pork Chump Chops', 29),
#  ('Smokies Sausage', 26),
#  ('Ambrette Seed', 25),
#  ('Murukku Packet', 25),
#  ('Baby Abalone', 23),
#  ('Mango', 22),
#  ('Americano Coffee', 21),
#  ('Crunch Bars', 18),
#  ('Hog Maw', 18),
#  ('Pickled Cauliflower', 17),
#  ('Cardamom', 15),
#  ('Vinegar', 14),
#  ('Mulberry', 13),
#  ('Mccormick Montreal Steak Seasoning', 10),
#  ('Pork Tripe', 10),
#  ('Tomato', 8),
#  ('Cadbury Double Decker Chocolate Bar', 0),
#  ('Orange Extract', 0)]

# %%
ranking={}
for i in range(len(ingredients)):
    ranking[sorted_d[i][0]]=i+1

# %%
ranking
# Out:
# {'Vegan Chorizo': 1,
#  'Organic Tartar Cream': 2,
#  'Vegan White Cake': 3,
#  'Vegan Marshmallow': 4,
#  'Vegan Chicken Strips': 5,
#  'Peanut Butter': 6,
#  'Chia Meal': 7,
#  'Celery Soup': 8,
#  'Muesli': 9,
#  'Strawberry Gelatin': 10,
#  'Vegetable Stock': 11,
#  'Vegan Puff Pastry Sheet': 12,
#  'Organic Peruvian Groundcherry': 13,
#  'Organic Maize': 14,
#  'Snickers Spread': 15,
#  'Giardiniera': 16,
#  'Vegan Carob Chips': 17,
#  'Tamarind': 18,
#  'Vegan Semisweet Chocolate Chips': 19,
#  'Apple Cinnamon Granola': 20,
#  'Salmon': 21,
#  'Munch Chocolate': 22,
#  'Arizona Seasoning': 23,
#  'Campari Tomato': 24,
#  'Pork Lungs': 25,
#  'Pork Chump Chops': 26,
#  'Smokies Sausage': 27,
#  'Ambrette Seed': 28,
#  'Murukku Packet': 29,
#  'Baby Abalone': 30,
#  'Mango': 31,
#  'Americano Coffee': 32,
#  'Crunch Bars': 33,
#  'Hog Maw': 34,
#  'Pickled Cauliflower': 35,
#  'Cardamom': 36,
#  'Vinegar': 37,
#  'Mulberry': 38,
#  'Mccormick Montreal Steak Seasoning': 39,
#  'Pork Tripe': 40,
#  'Tomato': 41,
#  'Cadbury Double Decker Chocolate Bar': 42,
#  'Orange Extract': 43}

# %%
ranking.keys()
# Out:
# dict_keys(['Vegan Chorizo', 'Organic Tartar Cream', 'Vegan White Cake', 'Vegan Marshmallow', 'Vegan Chicken Strips', 'Peanut Butter', 'Chia Meal', 'Celery Soup', 'Muesli', 'Strawberry Gelatin', 'Vegetable Stock', 'Vegan Puff Pastry Sheet', 'Organic Peruvian Groundcherry', 'Organic Maize', 'Snickers Spread', 'Giardiniera', 'Vegan Carob Chips', 'Tamarind', 'Vegan Semisweet Chocolate Chips', 'Apple Cinnamon Granola', 'Salmon', 'Munch Chocolate', 'Arizona Seasoning', 'Campari Tomato', 'Pork Lungs', 'Pork Chump Chops', 'Smokies Sausage', 'Ambrette Seed', 'Murukku Packet', 'Baby Abalone', 'Mango', 'Americano Coffee', 'Crunch Bars', 'Hog Maw', 'Pickled Cauliflower', 'Cardamom', 'Vinegar', 'Mulberry', 'Mccormick Montreal Steak Seasoning', 'Pork Tripe', 'Tomato', 'Cadbury Double Decker Chocolate Bar', 'Orange Extract'])
